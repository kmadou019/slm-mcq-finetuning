# %%
import pandas as pd
df = pd.read_csv('../data/finetuning_datasets/train_mcq_pairs_for_dpo.csv')
df.head()
# Out:
#              id                                             chosen  \
# 0  OIC-070-02-B  Question: Quelle est la prévalence des trouble...
# 1  OIC-245-22-B  Question: Quelle est l'origine de l'insuffisan...
# 2  OIC-227-08-A  Question: Quel est le stade ultime de l'insuff...
# 3  OIC-233-12-B  Question: Quel est le traitement médical indiq...
# 4  OIC-347-09-A  Question: Quels sont les éléments de gravité e...
#
#                                             rejected  chosen_source  \
# 0  Question: Quelle est la prévalence des trouble...    llama3_1_8b
# 1  Question: Selon l'étiologie de l'insuffisance ...  openbiollm_8b
# 2  Question: Quelles sont les caractéristiques pr...    llama3_1_8b
# 3  Question: Le traitement médical de l'insuffisa...    llama3_1_8b
# 4  Question: Quels sont les éléments de gravité e...  openbiollm_8b
#
#   rejected_source
# 0   openbiollm_8b
# 1     llama3_1_8b
# 2   openbiollm_8b
# 3   openbiollm_8b
# 4     llama3_1_8b

# %%
df.columns
# Out:
# Index(['id', 'chosen', 'rejected', 'chosen_source', 'rejected_source'], dtype='object')

# %%
chosen_part   = (df[['id', 'chosen', 'chosen_source']]
                 .rename(columns={'chosen': 'completion',
                                  'chosen_source': 'source'})
                 .assign(label=True))

rejected_part = (df[['id', 'rejected', 'rejected_source']]
                 .rename(columns={'rejected': 'completion',
                                  'rejected_source': 'source'})
                 .assign(label=False))

# combine and reorder columns ---------------------------------------------
new_df = (pd.concat([chosen_part, rejected_part], ignore_index=True)
            [['id', 'completion', 'label', 'source']])

new_df.head()
# Out:
#              id                                         completion  label  \
# 0  OIC-070-02-B  Question: Quelle est la prévalence des trouble...   True
# 1  OIC-245-22-B  Question: Quelle est l'origine de l'insuffisan...   True
# 2  OIC-227-08-A  Question: Quel est le stade ultime de l'insuff...   True
# 3  OIC-233-12-B  Question: Quel est le traitement médical indiq...   True
# 4  OIC-347-09-A  Question: Quels sont les éléments de gravité e...   True
#
#           source
# 0    llama3_1_8b
# 1  openbiollm_8b
# 2    llama3_1_8b
# 3    llama3_1_8b
# 4  openbiollm_8b

# %%
len(new_df)
# Out:
# 1520

# %%
new_df = new_df.drop_duplicates(subset=['completion'], keep='first')

# %%
len(new_df)
# Out:
# 1520

# %%
new_df = new_df.sample(frac=1).reset_index(drop=True)

# %%
len(new_df)
# Out:
# 1520

# %%
new_df.to_csv('../data/finetuning_datasets/train_mcq_pairs_for_kto.csv', index=False)

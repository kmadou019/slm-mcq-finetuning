# %%
import pandas as pd
df = pd.read_csv('../data/finetuning_datasets/train_mcq_pairs_for_dpo.csv')
df.head()
# Out:
#              id                                             chosen  \
# 0  OIC-047-20-B  Question: Quelle est la définition d'une tropi...
# 1  OIC-047-20-B  Question: Quelle est la définition d'une tropi...
# 2  OIC-047-20-B  Question: Quel type de tropie implique une dév...
# 3  OIC-047-20-B  Question: Quel type de tropie implique une dév...
# 4  OIC-047-20-B  Question: Qu'est-ce que l'exotropie?\na) Dévia...
#
#                                             rejected  chosen_source  \
# 0  Question: Quelle est la définition générale d'...  openbiollm_8b
# 1  Question: Quelle est la définition générale d'...  openbiollm_8b
# 2  Question: Quelle est la définition générale d'...      gemma2_9b
# 3  Question: Quelle est la définition générale d'...      gemma2_9b
# 4  Question: Quelle est la définition générale d'...    medGemma_4b
#
#   rejected_source
# 0    medGemma_27b
# 1    medGemma_27b
# 2    medGemma_27b
# 3    medGemma_27b
# 4    medGemma_27b

# %%
df.columns
# Out:
# Index(['id', 'chosen', 'rejected', 'chosen_source', 'rejected_source'], dtype='object')

# %%
chosen_part   = (df[['id', 'chosen', 'chosen_source']]
                 .rename(columns={'chosen': 'completion',
                                  'chosen_source': 'source'})
                 .assign(label=True))

rejected_part = (df[['id', 'rejected', 'rejected_source']]
                 .rename(columns={'rejected': 'completion',
                                  'rejected_source': 'source'})
                 .assign(label=False))

# combine and reorder columns ---------------------------------------------
new_df = (pd.concat([chosen_part, rejected_part], ignore_index=True)
            [['id', 'completion', 'label', 'source']])

new_df.head()
# Out:
#              id                                         completion  label  \
# 0  OIC-047-20-B  Question: Quelle est la définition d'une tropi...   True
# 1  OIC-047-20-B  Question: Quelle est la définition d'une tropi...   True
# 2  OIC-047-20-B  Question: Quel type de tropie implique une dév...   True
# 3  OIC-047-20-B  Question: Quel type de tropie implique une dév...   True
# 4  OIC-047-20-B  Question: Qu'est-ce que l'exotropie?\na) Dévia...   True
#
#           source
# 0  openbiollm_8b
# 1  openbiollm_8b
# 2      gemma2_9b
# 3      gemma2_9b
# 4    medGemma_4b

# %%
len(new_df)
# Out:
# 90

# %%
new_df = new_df.drop_duplicates(subset=['completion'], keep='first')

# %%
len(new_df)
# Out:
# 1520

# %%
new_df = new_df.sample(frac=1).reset_index(drop=True)

# %%
len(new_df)
# Out:
# 1520

# %%
new_df.to_csv('../data/finetuning_datasets/train_mcq_pairs_for_kto.csv', index=False)
